# %% [markdown]
# ## <center>This Notebook will be used to prepare the Bicycle Trip Data <br>for use in the Machine Learning Models</center>

# %%
# Importing requisite libraries
import pandas as pd
import os

# %%
# Set up data path and data file name
data_path = 'data'

# %%
# Import Specialized bike data to dataframe
sp_data = 'SpecializedTrips.csv'
sp_df = pd.read_csv(os.path.join(data_path, sp_data))
sp_df
# Out:
#         Date               Destination  Miles  Hours  Minutes  Duration  Speed
# 0    5/28/16                     CP BL   7.99    NaN     50.0      0.83   9.59
# 1    6/19/16             Down ES Up ES  13.98    1.0     51.0      1.85   7.56
# 2     7/3/16             Down ES UP WS  17.84    2.0     10.0      2.17   8.23
# 3    7/10/16             Down ES UP WS  18.38    2.0     20.0      2.33   7.88
# 4    7/16/16             Down ES UP WS  17.99    2.0      5.0      2.08   8.64
# ..       ...                       ...    ...    ...      ...       ...    ...
# 209   6/7/21              Dn ES Up LWS  16.45    1.0     58.0      1.97   8.36
# 210  6/16/21     Up Dn WS to GWB Up ES  30.18    3.0     32.0      3.53   8.54
# 211  6/19/21  Wards Island Exploration  16.48    1.0     59.0      1.98   8.31
# 212  6/20/21              Dn ES Up LWS  16.30    2.0      3.0      2.05   7.95
# 213  6/23/21              Dn UWS Up ES  21.56    2.0     26.0      2.43   8.86
#
# [214 rows x 7 columns]

# %%
# Add Label for Specialized Data
sp_df['Type'] = "Specialized"
sp_df
# Out:
#         Date               Destination  Miles  Hours  Minutes  Duration  \
# 0    5/28/16                     CP BL   7.99    NaN     50.0      0.83
# 1    6/19/16             Down ES Up ES  13.98    1.0     51.0      1.85
# 2     7/3/16             Down ES UP WS  17.84    2.0     10.0      2.17
# 3    7/10/16             Down ES UP WS  18.38    2.0     20.0      2.33
# 4    7/16/16             Down ES UP WS  17.99    2.0      5.0      2.08
# ..       ...                       ...    ...    ...      ...       ...
# 209   6/7/21              Dn ES Up LWS  16.45    1.0     58.0      1.97
# 210  6/16/21     Up Dn WS to GWB Up ES  30.18    3.0     32.0      3.53
# 211  6/19/21  Wards Island Exploration  16.48    1.0     59.0      1.98
# 212  6/20/21              Dn ES Up LWS  16.30    2.0      3.0      2.05
# 213  6/23/21              Dn UWS Up ES  21.56    2.0     26.0      2.43
#
#      Speed         Type
# 0     9.59  Specialized
# 1     7.56  Specialized
# 2     8.23  Specialized
# 3     7.88  Specialized
# 4     8.64  Specialized
# ..     ...          ...
# 209   8.36  Specialized
# 210   8.54  Specialized
# 211   8.31  Specialized
# 212   7.95  Specialized
# 213   8.86  Specialized
#
# [214 rows x 8 columns]

# %%
# Import Citibike data to datafram
cb_data = 'CitibikeTrips.csv'
cb_df = pd.read_csv(os.path.join(data_path, cb_data))
cb_df
# Out:
#         Date         Destination  Miles  Hours  Minutes  Duration  Speed
# 0    6/15/16    Citibike to Work   1.04    NaN        9      0.15   6.93
# 1    6/17/16    Citibike to Work   1.20    NaN       13      0.22   5.54
# 2    6/17/16     Work to Village   4.69    NaN       40      0.67   7.04
# 3    6/21/16    Citibike to Work   1.12    NaN       10      0.17   6.72
# 4    6/21/16  Citibike from Work   0.78    NaN        7      0.12   6.69
# ..       ...                 ...    ...    ...      ...       ...    ...
# 151  3/26/21       To El Tepeyac   3.10    NaN       28      0.47   6.64
# 152  5/11/21           To Toyota   2.49    NaN       21      0.35   7.11
# 153  6/16/21     To Kalustiyan's   1.89    NaN       16      0.27   7.09
# 154  6/16/21    From Kalustyan's   2.43    NaN       22      0.37   6.63
# 155  6/25/21          To Despana   4.28    NaN       39      0.65   6.58
#
# [156 rows x 7 columns]

# %%
# Add Label for Citibike Data
cb_df['Type'] = 'Citibike'
cb_df
# Out:
#         Date         Destination  Miles  Hours  Minutes  Duration  Speed  \
# 0    6/15/16    Citibike to Work   1.04    NaN        9      0.15   6.93
# 1    6/17/16    Citibike to Work   1.20    NaN       13      0.22   5.54
# 2    6/17/16     Work to Village   4.69    NaN       40      0.67   7.04
# 3    6/21/16    Citibike to Work   1.12    NaN       10      0.17   6.72
# 4    6/21/16  Citibike from Work   0.78    NaN        7      0.12   6.69
# ..       ...                 ...    ...    ...      ...       ...    ...
# 151  3/26/21       To El Tepeyac   3.10    NaN       28      0.47   6.64
# 152  5/11/21           To Toyota   2.49    NaN       21      0.35   7.11
# 153  6/16/21     To Kalustiyan's   1.89    NaN       16      0.27   7.09
# 154  6/16/21    From Kalustyan's   2.43    NaN       22      0.37   6.63
# 155  6/25/21          To Despana   4.28    NaN       39      0.65   6.58
#
#          Type
# 0    Citibike
# 1    Citibike
# 2    Citibike
# 3    Citibike
# 4    Citibike
# ..        ...
# 151  Citibike
# 152  Citibike
# 153  Citibike
# 154  Citibike
# 155  Citibike
#
# [156 rows x 8 columns]

# %%
# Combine the dataframes
all_data = [sp_df, cb_df]
all_df = pd.concat(all_data)
all_df
# Out:
#         Date       Destination  Miles  Hours  Minutes  Duration  Speed  \
# 0    5/28/16             CP BL   7.99    NaN     50.0      0.83   9.59
# 1    6/19/16     Down ES Up ES  13.98    1.0     51.0      1.85   7.56
# 2     7/3/16     Down ES UP WS  17.84    2.0     10.0      2.17   8.23
# 3    7/10/16     Down ES UP WS  18.38    2.0     20.0      2.33   7.88
# 4    7/16/16     Down ES UP WS  17.99    2.0      5.0      2.08   8.64
# ..       ...               ...    ...    ...      ...       ...    ...
# 151  3/26/21     To El Tepeyac   3.10    NaN     28.0      0.47   6.64
# 152  5/11/21         To Toyota   2.49    NaN     21.0      0.35   7.11
# 153  6/16/21   To Kalustiyan's   1.89    NaN     16.0      0.27   7.09
# 154  6/16/21  From Kalustyan's   2.43    NaN     22.0      0.37   6.63
# 155  6/25/21        To Despana   4.28    NaN     39.0      0.65   6.58
#
#             Type
# 0    Specialized
# 1    Specialized
# 2    Specialized
# 3    Specialized
# 4    Specialized
# ..           ...
# 151     Citibike
# 152     Citibike
# 153     Citibike
# 154     Citibike
# 155     Citibike
#
# [370 rows x 8 columns]

# %%
# Sort the combined dataframe randomly
all_df = all_df.sample(frac=1).reset_index(drop=True)
all_df
# Out:
#          Date              Destination  Miles  Hours  Minutes  Duration  \
# 0      7/8/18                    CP BL   7.04    NaN     47.0      0.78
# 1    10/12/16       Citibike from Work   0.84    NaN      7.0      0.12
# 2     8/23/16         Citibike to Work   1.46    NaN     15.0      0.25
# 3     12/2/16       Citibike from Work   0.92    NaN      7.0      0.12
# 4      8/4/16         Citibike to Work   1.40    NaN     11.0      0.18
# ..        ...                      ...    ...    ...      ...       ...
# 365  12/24/20             Dn ES Up LWS  13.79    1.0     41.0      1.68
# 366   6/23/20      UWS Thru CP to GWB+  22.42    2.0     54.0      2.90
# 367   10/5/16  Citibike to Work Midday   1.16    NaN     13.0      0.22
# 368  12/11/20              Dn ES Up WS  21.60    2.0     36.0      2.60
# 369  10/21/16       Citibike from Work   3.51    NaN     26.0      0.43
#
#      Speed         Type
# 0     8.99  Specialized
# 1     7.20     Citibike
# 2     5.84     Citibike
# 3     7.89     Citibike
# 4     7.64     Citibike
# ..     ...          ...
# 365   8.19  Specialized
# 366   7.73  Specialized
# 367   5.35     Citibike
# 368   8.31  Specialized
# 369   8.10     Citibike
#
# [370 rows x 8 columns]

# %%
# Export to CSV file for use in Machine Learning Model
all_data_file = 'all_data.csv'
all_df.to_csv(os.path.join(data_path, all_data_file), index=False)
