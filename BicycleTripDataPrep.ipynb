# %% [markdown]
# ## <center>This Notebook will be used to prepare the Bicycle Trip Data <br>for use in the Machine Learning Models</center>

# %%
# Importing requisite libraries
import pandas as pd
import os

# %%
# Set up data path
data_path = 'data/'

# %%
# Import Specialized bike data to dataframe
sp_data = 'SpecializedTrips.csv'
sp_df = pd.read_csv(os.path.join(data_path, sp_data))
sp_df
# Out:
#         Date          Destination  Miles  Hours  Minutes  Duration  Speed
# 0    5/28/16                CP BL   7.99    NaN     50.0      0.83   9.59
# 1    6/19/16        Down ES Up ES  13.98    1.0     51.0      1.85   7.56
# 2     7/3/16        Down ES UP WS  17.84    2.0     10.0      2.17   8.23
# 3    7/10/16        Down ES UP WS  18.38    2.0     20.0      2.33   7.88
# 4    7/16/16        Down ES UP WS  17.99    2.0      5.0      2.08   8.64
# ..       ...                  ...    ...    ...      ...       ...    ...
# 190  1/17/21         Dn ES Up LWS  15.41    2.0      2.0      2.03   7.58
# 191  2/24/21         Dn ES Up LWS  14.65    1.0     54.0      1.90   7.71
# 192   3/9/21         Dn ES Up LWS  15.90    2.0     20.0      2.33   6.81
# 193  3/21/21         Dn ES Up LWS  15.74    2.0      1.0      2.02   7.80
# 194  3/27/21  Dn ES Up UWS to 135  25.17    3.0      6.0      3.10   8.12
#
# [195 rows x 7 columns]

# %%
# Label to Specialized Data
sp_df['Type'] = "Specialized"
sp_df
# Out:
#         Date          Destination  Miles  Hours  Minutes  Duration  Speed  \
# 0    5/28/16                CP BL   7.99    NaN     50.0      0.83   9.59
# 1    6/19/16        Down ES Up ES  13.98    1.0     51.0      1.85   7.56
# 2     7/3/16        Down ES UP WS  17.84    2.0     10.0      2.17   8.23
# 3    7/10/16        Down ES UP WS  18.38    2.0     20.0      2.33   7.88
# 4    7/16/16        Down ES UP WS  17.99    2.0      5.0      2.08   8.64
# ..       ...                  ...    ...    ...      ...       ...    ...
# 190  1/17/21         Dn ES Up LWS  15.41    2.0      2.0      2.03   7.58
# 191  2/24/21         Dn ES Up LWS  14.65    1.0     54.0      1.90   7.71
# 192   3/9/21         Dn ES Up LWS  15.90    2.0     20.0      2.33   6.81
# 193  3/21/21         Dn ES Up LWS  15.74    2.0      1.0      2.02   7.80
# 194  3/27/21  Dn ES Up UWS to 135  25.17    3.0      6.0      3.10   8.12
#
#             Type
# 0    Specialized
# 1    Specialized
# 2    Specialized
# 3    Specialized
# 4    Specialized
# ..           ...
# 190  Specialized
# 191  Specialized
# 192  Specialized
# 193  Specialized
# 194  Specialized
#
# [195 rows x 8 columns]

# %%
# Import Citibike data to datafram
cb_data = 'CitibikeTrips.csv'
cb_df = pd.read_csv(os.path.join(data_path, cb_data))
cb_df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 8: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-f20120c93651> in <module>
#       1 # Import Citibike data to datafram
#       2 cb_data = 'CitibikeTrips.csv'
# ----> 3 cb_df = pd.read_csv(os.path.join(data_path, cb_data))
#       4 cb_df
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 8: invalid start byte
